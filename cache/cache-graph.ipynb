# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("cache-table.csv", names=["size", "school", "house"])

# %%
plt.xlabel("size[KB]")
plt.ylabel("speed[nsec]")
plt.xscale("log", base = 2)
plt.plot(df["size"],df["school"])

# %%
plt.xlabel("size[KB]")
plt.ylabel("speed[nsec]")
plt.xscale("log", base = 2)
plt.plot(df["size"],df["house"])
